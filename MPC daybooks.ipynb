# %%
import pandas as pd
import numpy as np
import os
import xlsxwriter

# %% [markdown]
# iterate through all txt files in a directory

# %%
directory = '/Users/michaelkingston/PycharmProjects/principles_of_programming-main/data/07 JUL 2020'

# %%
for filename in os.listdir(directory):
    if filename.endswith(".txt"):
        mpc_df = pd.read_fwf(filename, colspecs=[(0,9), (10,18), (19,25), (26,28), (33,40), (56,67), (68,92), (93,100), (101,111)], names=[('TRANS-'), ('TRANSDAT'), ('ACC'), ('CC'), ('PRD'), ('AMOUNT'), ('TEXT'), ('WORK.C'), ('WO-NO')], dtype={'TRANS-': object, 'TRANSDAT': object, 'ACC': object, 'CC': object, 'PRD': object, 'AMOUNT': object, 'TEXT': object, 'WORK.C': object, 'WO-NO': object,},header=4, skiprows=1)
        data_with_index = mpc_df.set_index("ACC")
        mpc_july20_df = pd.DataFrame()
        data_with_index = data_with_index.drop(['------', 'ONS', 'D', 'Z', 'L', 'N', 'T', 'PRJ', 'ACC', '20===', '======', 'TRAN', '0004', 'IANCES', 'S U', 'T O', 'OVERY', 'LIER I', 'I.P.', '- - -', 'CLOSED'])
        clean_mpc_df = data_with_index[data_with_index.index.notnull()]
        mpc_july20_df.append(clean_mpc_df)
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/fb/nz6kmlf12_5dr4y45r6_vm7h0000gn/T/ipykernel_10136/1416847989.py in <module>
#       1 for filename in os.listdir(directory):
#       2     if filename.endswith(".txt"):
# ----> 3         mpc_df = pd.read_fwf(filename, colspecs=[(0,9), (10,18), (19,25), (26,28), (33,40), (56,67), (68,92), (93,100), (101,111)], names=[('TRANS-'), ('TRANSDAT'), ('ACC'), ('CC'), ('PRD'), ('AMOUNT'), ('TEXT'), ('WORK.C'), ('WO-NO')], dtype={'TRANS-': object, 'TRANSDAT': object, 'ACC': object, 'CC': object, 'PRD': object, 'AMOUNT': object, 'TEXT': object, 'WORK.C': object, 'WO-NO': object,},header=4, skiprows=1)
#       4         data_with_index = mpc_df.set_index("ACC")
#       5         mpc_july20_df = pd.DataFrame()
#
# ...

# %% [markdown]
# what happens if i don't specify data-type?

# %%
clean_mpc_df.head(3226)
# Out:
#            TRANS-  TRANSDAT   CC     PRD   AMOUNT        TEXT WORK.C  \
# ACC
# 001049  000473148  01-06-20  NaN     NaN   463.63  14-01-0102    NaN
# 001021        NaN       NaN   60  ACBBOT  463.63-  14-01-0102    NaN
# 001049  000473149  01-06-20  NaN     NaN    42.99  16-03-8117    NaN
# 001021        NaN       NaN   60  ACBBOT   42.99-  16-03-8117    NaN
# 001049  000473150  01-06-20  NaN     NaN     0.05  14-05-0041    NaN
# ...           ...       ...  ...     ...      ...         ...    ...
# 350000        NaN       NaN   60     NaN   95.98-  VK5000 POM     43
# 100112  000477381  01-06-20   60  ACBBOT   427.08  16-01-7925    NaN
# 001049        NaN       NaN  NaN     NaN  427.08-  16-01-7925    NaN
# 100112  000477382  01-06-20   60  ACBBOT   427.08  16-01-7925    NaN
# 001049        NaN       NaN  NaN     NaN  427.08-  16-01-7925    NaN
#
#              WO-NO
# ACC
# 001049  0000863677
# 001021  0000863677
# 001049  0000863677
# 001021  0000863677
# 001049  0000863677
# ...

# %%
# clean_mpc_df.to_excel('clean_data.xlsx')

# %% [markdown]
# # This is pretty clean now, but...

# %% [markdown]
# # I want to...
#
#     - drop unnecessary columns
#
#     - correct the data types
#
#     - deal with the NaNs
#
#     - correct sequence of columns
#
#     - move the negative sign on value column
#
#     - compare to excel VBA output
#
#     - test edge cases & corner cases
#
#     - set up the loop through directory and df.append

# %% [markdown]
# # Automate the presentation
#
#     - Pivot
#
#     - Analyse data
#
#     - present data using Plotly or panel for interactive graphs
#
#     - Export as xlsx
#
#     - package up in a tkinter gui
